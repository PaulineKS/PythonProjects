# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulineKS/PythonProjects/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Missing Value check

# %%
missing_values = ['n/a','na','NaN','--']
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values=missing_values)
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
#Column Names
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.dtypes
# Out:
# School DBN                      object
# School Name                     object
# School Level                    object
# Regents Exam                    object
# Year                             int64
# Total Tested                     int64
# Mean Score                      object
# Number Scoring Below 65         object
# Percent Scoring Below 65        object
# Number Scoring 65 or Above      object
# Percent Scoring 65 or Above     object
# Number Scoring 80 or Above      object
# Percent Scoring 80 or Above     object
# Number Scoring CR              float64
# Percent Scoring CR             float64
# dtype: object

# %%
#Renaming Column
df.rename(columns= {'Year': 'Passing Year'}, inplace=True)
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Passing Year  Total Tested Mean Score  \
# 0               Common Core Algebra          2017             4          s
# ...

# %%
#Analysis
df.groupby('School Name').count()
# Out:
#                                                     School DBN  School Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
# ...

# %%
#Different Exams for children
df['Regents Exam'].value_counts()
# Out:
# Common Core Algebra                29254
# Living Environment                 25539
# U.S. History and Government        20426
# Common Core English                19878
# Global History and Geography       19192
# Physical Settings/Earth Science    15971
# Common Core Geometry               15267
# Physical Settings/Chemistry        11670
# English                            11091
# Integrated Algebra                 11022
# Algebra2/Trigonometry              10788
# Geometry                            8509
# Common Core Algebra2                7915
# Physical Settings/Physics           5799
# Name: Regents Exam, dtype: int64

# %%
df['Regents Exam'].value_counts().plot(kind='bar')
#Highest Exam taken is for Common Core Algebra

# %%
#Passing Years considered
df.groupby(['Passing Year'])['Total Tested'].count()
# Out:
# Passing Year
# 2015    72768
# 2016    76123
# 2017    63440
# Name: Total Tested, dtype: int64

# %%
df['Passing Year'].value_counts().plot(kind='bar')
#Highest exams taken in 2016 and lowest 2017

# %% [markdown]
# Comparison Study Basis School Name

# %%
df.groupby('School Name').count()
# Out:
#                                                     School DBN  School Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
# ...

# %%
df_francis_lewisHS = df[df['School Name']== 'Francis Lewis High School']
df_francis_lewisHS
# Out:
#        School DBN                School Name School Level  \
# 14549      26Q430  Francis Lewis High School  High school
# 14550      26Q430  Francis Lewis High School  High school
# 14551      26Q430  Francis Lewis High School  High school
# 14552      26Q430  Francis Lewis High School  High school
# 14553      26Q430  Francis Lewis High School  High school
# ...           ...                        ...          ...
# 194228     26Q430  Francis Lewis High School  High school
# 194229     26Q430  Francis Lewis High School  High school
# 194230     26Q430  Francis Lewis High School  High school
# 194231     26Q430  Francis Lewis High School  High school
# 194232     26Q430  Francis Lewis High School  High school
#
#                        Regents Exam  Passing Year  Total Tested Mean Score  \
# 14549         Algebra2/Trigonometry          2015           845       77.8
# 14550         Algebra2/Trigonometry          2016           889       76.7
# ...

# %%
df_francis_lewisHS['Total Tested'].describe()
# Out:
# count     490.000000
# mean      304.683673
# std       295.056668
# min         1.000000
# 25%        61.250000
# 50%       203.500000
# 75%       490.750000
# max      1264.000000
# Name: Total Tested, dtype: float64

# %%
df_francis_lewisHS['Total Tested'].sum()
# Out:
# 149295

# %%
df_francis_lewisHS['Total Tested'].mean()
# Out:
# 304.68367346938777

# %%
FL_score_per_year=df_francis_lewisHS[['Passing Year','Total Tested','Number Scoring CR','Percent Scoring CR']]
FL_score_per_year
# Out:
#         Passing Year  Total Tested  Number Scoring CR  Percent Scoring CR
# 14549           2015           845              461.0                54.6
# 14550           2016           889              455.0                51.2
# 14551           2017            19                4.0                21.1
# 14552           2015           541              266.0                49.2
# 14553           2016           900              744.0                82.7
# ...              ...           ...                ...                 ...
# 194228          2017           670                NaN                 NaN
# 194229          2017            64                NaN                 NaN
# 194230          2017           225                NaN                 NaN
# 194231          2017             9                NaN                 NaN
# 194232          2017           181                NaN                 NaN
#
# [490 rows x 4 columns]

# %%
FL_best_score_per_year=df_francis_lewisHS[['Passing Year','Total Tested','Number Scoring 80 or Above','Percent Scoring 80 or Above','Number Scoring Below 65','Percent Scoring Below 65']]
FL_best_score_per_year
# Out:
#         Passing Year  Total Tested Number Scoring 80 or Above  \
# 14549           2015           845                        461
# 14550           2016           889                        455
# 14551           2017            19                          4
# 14552           2015           541                         58
# 14553           2016           900                        478
# ...              ...           ...                        ...
# 194228          2017           670                        496
# 194229          2017            64                         38
# 194230          2017           225                        115
# 194231          2017             9                          8
# 194232          2017           181                        129
#
#        Percent Scoring 80 or Above Number Scoring Below 65  \
# 14549                         54.6                     176
# 14550                         51.2                     210
# ...

# %%
df_ACORN_CommunityHS = df[df['School Name']== 'ACORN Community High School']
df_ACORN_CommunityHS
# Out:
#        School DBN                  School Name School Level  \
# 8657       13K499  ACORN Community High School  High school
# 8658       13K499  ACORN Community High School  High school
# 8659       13K499  ACORN Community High School  High school
# 8660       13K499  ACORN Community High School  High school
# 8661       13K499  ACORN Community High School  High school
# ...           ...                          ...          ...
# 172332     13K499  ACORN Community High School  High school
# 172333     13K499  ACORN Community High School  High school
# 172334     13K499  ACORN Community High School  High school
# 172335     13K499  ACORN Community High School  High school
# 172336     13K499  ACORN Community High School  High school
#
#                        Regents Exam  Passing Year  Total Tested Mean Score  \
# 8657          Algebra2/Trigonometry          2015            19         44
# 8658          Algebra2/Trigonometry          2016             6       50.5
# ...

# %%
AC_score_per_year=df_ACORN_CommunityHS[['Passing Year','Total Tested','Number Scoring CR','Percent Scoring CR']]
AC_score_per_year
# Out:
#         Passing Year  Total Tested  Number Scoring CR  Percent Scoring CR
# 8657            2015            19                0.0                 0.0
# 8658            2016             6                1.0                16.7
# 8659            2015            64                2.0                 3.1
# 8660            2016           120               22.0                18.3
# 8661            2017            82               36.0                43.9
# ...              ...           ...                ...                 ...
# 172332          2017             1                NaN                 NaN
# 172333          2017            94                NaN                 NaN
# 172334          2017            16                NaN                 NaN
# 172335          2017             1                NaN                 NaN
# 172336          2017             3                NaN                 NaN
#
# [364 rows x 4 columns]

# %%
AC_score_per_year=df_ACORN_CommunityHS[['Passing Year','Total Tested','Number Scoring 80 or Above','Percent Scoring 80 or Above','Number Scoring Below 65','Percent Scoring Below 65']]
AC_score_per_year
# Out:
#         Passing Year  Total Tested Number Scoring 80 or Above  \
# 8657            2015            19                          0
# 8658            2016             6                          1
# 8659            2015            64                          0
# 8660            2016           120                          2
# 8661            2017            82                          3
# ...              ...           ...                        ...
# 172332          2017             1                          s
# 172333          2017            94                         14
# 172334          2017            16                          2
# 172335          2017             1                          s
# 172336          2017             3                          s
#
#        Percent Scoring 80 or Above Number Scoring Below 65  \
# 8657                             0                      17
# 8658                          16.7                       5
# ...

# %% [markdown]
# Comparison Between Acron Community HS and Fransis LEwis HS basis Percent Scoring CR

# %%
AC=df_ACORN_CommunityHS[['School Name','Passing Year','Total Tested','Percent Scoring CR']]
FL=df_francis_lewisHS[['School Name','Passing Year','Total Tested','Percent Scoring CR']]
FL
# Out:
#                       School Name  Passing Year  Total Tested  \
# 14549   Francis Lewis High School          2015           845
# 14550   Francis Lewis High School          2016           889
# 14551   Francis Lewis High School          2017            19
# 14552   Francis Lewis High School          2015           541
# 14553   Francis Lewis High School          2016           900
# ...                           ...           ...           ...
# 194228  Francis Lewis High School          2017           670
# 194229  Francis Lewis High School          2017            64
# 194230  Francis Lewis High School          2017           225
# 194231  Francis Lewis High School          2017             9
# 194232  Francis Lewis High School          2017           181
#
#         Percent Scoring CR
# 14549                 54.6
# 14550                 51.2
# 14551                 21.1
# 14552                 49.2
# 14553                 82.7
# ...                    ...
# ...

# %%
AC
# Out:
#                         School Name  Passing Year  Total Tested  \
# 8657    ACORN Community High School          2015            19
# 8658    ACORN Community High School          2016             6
# 8659    ACORN Community High School          2015            64
# 8660    ACORN Community High School          2016           120
# 8661    ACORN Community High School          2017            82
# ...                             ...           ...           ...
# 172332  ACORN Community High School          2017             1
# 172333  ACORN Community High School          2017            94
# 172334  ACORN Community High School          2017            16
# 172335  ACORN Community High School          2017             1
# 172336  ACORN Community High School          2017             3
#
#         Percent Scoring CR
# 8657                   0.0
# 8658                  16.7
# 8659                   3.1
# 8660                  18.3
# 8661                  43.9
# ...                    ...
# ...

# %%
merge= pd.merge(FL_score_per_year, AC_score_per_year, on='Passing Year')
merge
# Out:
#        Passing Year  Total Tested_x  Number Scoring CR  Percent Scoring CR  \
# 0              2015             845              461.0                54.6
# 1              2015             845              461.0                54.6
# 2              2015             845              461.0                54.6
# 3              2015             845              461.0                54.6
# 4              2015             845              461.0                54.6
# ...             ...             ...                ...                 ...
# 60331          2017             181                NaN                 NaN
# 60332          2017             181                NaN                 NaN
# 60333          2017             181                NaN                 NaN
# 60334          2017             181                NaN                 NaN
# 60335          2017             181                NaN                 NaN
#
# ...

# %%
merge1= pd.merge(FL, AC, on='Passing Year')
merge1
# Out:
#                    School Name_x  Passing Year  Total Tested_x  \
# 0      Francis Lewis High School          2015             845
# 1      Francis Lewis High School          2015             845
# 2      Francis Lewis High School          2015             845
# 3      Francis Lewis High School          2015             845
# 4      Francis Lewis High School          2015             845
# ...                          ...           ...             ...
# 60331  Francis Lewis High School          2017             181
# 60332  Francis Lewis High School          2017             181
# 60333  Francis Lewis High School          2017             181
# 60334  Francis Lewis High School          2017             181
# 60335  Francis Lewis High School          2017             181
#
#        Percent Scoring CR_x                School Name_y  Total Tested_y  \
# 0                      54.6  ACORN Community High School              19
# ...

# %%
FL_AC= merge1.groupby(['School Name_x','School Name_y']).mean()
FL_AC
# Out:
#                                                        Passing Year  \
# School Name_x             School Name_y
# Francis Lewis High School ACORN Community High School   2015.833134
#
#                                                        Total Tested_x  \
# School Name_x             School Name_y
# Francis Lewis High School ACORN Community High School      303.169584
#
#                                                        Percent Scoring CR_x  \
# School Name_x             School Name_y
# Francis Lewis High School ACORN Community High School             54.805873
#
#                                                        Total Tested_y  \
# School Name_x             School Name_y
# Francis Lewis High School ACORN Community High School       30.184467
#
#                                                        Percent Scoring CR_y
# School Name_x             School Name_y
# Francis Lewis High School ACORN Community High School             17.274544

# %%
FL_AC[['Percent Scoring CR_x','Percent Scoring CR_y']].plot(kind='bar')

# %% [markdown]
# 1. Statistical Analysis of school comparison- We understand Fransis Lewis School Performance stands better over Acron Community basis Percent Scoring CR Study
# 2. Highest exams taken in 2016 and lowest 2017 across all schools
# 3. Highest Exam taken is for Common Core Algebra across all schools in 3 compared years
